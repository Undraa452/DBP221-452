# %%
import pandas as pd

# %%
pd.read_excel("week7.xlsx")
# Out:
#           Order ID Order Date Customer ID      Segment     Region  \
# 0   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 1   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 2   CA-2016-138688 2016-06-12    MO-17950  Байгууллага    Хан-Уул
# 3   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# 4   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# ..             ...        ...         ...          ...        ...
# 95  US-2017-109484 2017-11-06    JR-15700       Гишүүн    Хан-Уул
# 96  CA-2017-161018 2017-11-09    AJ-10945       Гишүүн  Сүхбаатар
# 97  CA-2017-157833 2017-06-17    BM-11575     Хувь хүн    Хан-Уул
# 98  CA-2016-149223 2016-09-06    CV-12805  Байгууллага  Чингэлтэй
# 99  CA-2016-158568 2016-08-29    DK-12835       Гишүүн  Чингэлтэй
#
#                            Category             Product Name  Price  Quantity  \
# 0                    Чихэр, печенье       Shokolinsen 250 гр   3300         2
# ...

# %%
OrderID = pd.read_excel("week7.xlsx", index_col=0, header=0, usecols="A")
OrderID
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
OrderDate = pd.read_excel("week7.xlsx", index_col=0, header=0, usecols="B")
#OrderDate

# %%
CustomerID = pd.read_excel("week7.xlsx", index_col=0, header=0, usecols="C")
#CustomerID

# %%
Segment = pd.read_excel("week7.xlsx", index_col=0, header=0, usecols="D")
#Segment

# %%
Region = pd.read_excel("week7.xlsx", index_col=0, header=0, usecols="E")
#Region

# %%
Category = pd.read_excel("week7.xlsx", index_col=0, header=0, usecols="F")
#Category

# %%
ProductName = pd.read_excel("week7.xlsx", index_col=0, header=0, usecols="G")
#ProductName

# %%
Price = pd.read_excel("week7.xlsx", index_col=0, header=0, usecols="H")
#Price

# %%
Quantity = pd.read_excel("week7.xlsx", index_col=0, header=0, usecols="I")
#Quantity

# %%
Discount = pd.read_excel("week7.xlsx", index_col=0, header=0, usecols="J")
#Discount

# %%
Sales = pd.read_excel("week7.xlsx", index_col=0, header=0, usecols="K")
#Sales

# %%
df = pd.read_excel("week7.xlsx", index_col=0)
df
# Out:
#                Order Date Customer ID      Segment     Region  \
# Order ID
# CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# CA-2016-138688 2016-06-12    MO-17950  Байгууллага    Хан-Уул
# US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# ...                   ...         ...          ...        ...
# US-2017-109484 2017-11-06    JR-15700       Гишүүн    Хан-Уул
# CA-2017-161018 2017-11-09    AJ-10945       Гишүүн  Сүхбаатар
# CA-2017-157833 2017-06-17    BM-11575     Хувь хүн    Хан-Уул
# CA-2016-149223 2016-09-06    CV-12805  Байгууллага  Чингэлтэй
# CA-2016-158568 2016-08-29    DK-12835       Гишүүн  Чингэлтэй
#
#                                        Category             Product Name  \
# Order ID
# CA-2016-152156                   Чихэр, печенье       Shokolinsen 250 гр
# ...
