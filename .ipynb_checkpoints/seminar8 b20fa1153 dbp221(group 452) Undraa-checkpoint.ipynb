# %%
import pandas as pd

# %%
df = pd.read_excel("week7.xlsx")
df
# Out:
#           Order ID Order Date Customer ID      Segment     Region  \
# 0   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 1   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 2   CA-2016-138688 2016-06-12    MO-17950  Байгууллага    Хан-Уул
# 3   US-2015-108966 2015-10-11    JO-15550     Хувь хүн        NaN
# 4   US-2015-108966 2015-10-11    JO-15550     Хувь хүн        NaN
# ..             ...        ...         ...          ...        ...
# 95  US-2017-109484 2017-11-06    JR-15700       Гишүүн    Хан-Уул
# 96             NaN        NaT         NaN          NaN        NaN
# 97             NaN        NaT         NaN          NaN        NaN
# 98  CA-2016-149223 2016-09-06    CV-12805  Байгууллага  Чингэлтэй
# 99  CA-2016-158568 2016-08-29    DK-12835       Гишүүн  Чингэлтэй
#
#                            Category             Product Name  Price  Quantity  \
# 0                    Чихэр, печенье       Shokolinsen 250 гр    NaN       NaN
# 1            OO ийн цаас, сальфетка      Хэрэглээ 00ийн цаас    NaN       NaN
# 2                    Чихэр, печенье  Алимтай жигнэмэг 230 гр    NaN       NaN
# 3                         Хиам бууз      Золотой янта 500 гр    NaN       NaN
# 4                          Ундаа ус             Punch 450 мл    NaN       NaN
# ..                              ...                      ...    ...       ...
# 95  Компот варенье, хүүхдийн тэжээл            Hainich нухаш    NaN       NaN
# 96                              NaN                      NaN    NaN       NaN
# 97                              NaN                      NaN    NaN       NaN
# 98                        Архи пиво              Арвай 0.100    NaN       NaN
# 99                     Бэлэн гоймон     Тэйсти гоймон 110 гр    NaN       NaN
#
#     Discount    Sales
# 0       0.00   6600.0
# 1       0.00   1500.0
# 2       0.00   6200.0
# 3       0.00  14000.0
# 4       0.00   2300.0
# ..       ...      ...
# 95      0.03   3201.0
# 96       NaN      NaN
# 97       NaN      NaN
# 98      0.00  12000.0
# 99      0.03  12222.0
#
# [100 rows x 11 columns]

# %%
df1 = df.dropna(axis = 1, how = 'all')
df1
# Out:
#           Order ID Order Date Customer ID      Segment     Region  \
# 0   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 1   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 2   CA-2016-138688 2016-06-12    MO-17950  Байгууллага    Хан-Уул
# 3   US-2015-108966 2015-10-11    JO-15550     Хувь хүн        NaN
# 4   US-2015-108966 2015-10-11    JO-15550     Хувь хүн        NaN
# ..             ...        ...         ...          ...        ...
# 95  US-2017-109484 2017-11-06    JR-15700       Гишүүн    Хан-Уул
# 96             NaN        NaT         NaN          NaN        NaN
# 97             NaN        NaT         NaN          NaN        NaN
# 98  CA-2016-149223 2016-09-06    CV-12805  Байгууллага  Чингэлтэй
# 99  CA-2016-158568 2016-08-29    DK-12835       Гишүүн  Чингэлтэй
#
#                            Category             Product Name  Discount  \
# 0                    Чихэр, печенье       Shokolinsen 250 гр      0.00
# 1            OO ийн цаас, сальфетка      Хэрэглээ 00ийн цаас      0.00
# 2                    Чихэр, печенье  Алимтай жигнэмэг 230 гр      0.00
# 3                         Хиам бууз      Золотой янта 500 гр      0.00
# 4                          Ундаа ус             Punch 450 мл      0.00
# ..                              ...                      ...       ...
# 95  Компот варенье, хүүхдийн тэжээл            Hainich нухаш      0.03
# 96                              NaN                      NaN       NaN
# 97                              NaN                      NaN       NaN
# 98                        Архи пиво              Арвай 0.100      0.00
# 99                     Бэлэн гоймон     Тэйсти гоймон 110 гр      0.03
#
#       Sales
# 0    6600.0
# 1    1500.0
# 2    6200.0
# 3   14000.0
# 4    2300.0
# ..      ...
# 95   3201.0
# 96      NaN
# 97      NaN
# 98  12000.0
# 99  12222.0
#
# [100 rows x 9 columns]

# %%
df2 = df1.dropna(axis = 0, how = 'all')
df2
# Out:
#           Order ID Order Date Customer ID      Segment     Region  \
# 0   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 1   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 2   CA-2016-138688 2016-06-12    MO-17950  Байгууллага    Хан-Уул
# 3   US-2015-108966 2015-10-11    JO-15550     Хувь хүн        NaN
# 4   US-2015-108966 2015-10-11    JO-15550     Хувь хүн        NaN
# ..             ...        ...         ...          ...        ...
# 93  CA-2015-149587 2015-01-31    NS-18640     Хувь хүн        NaN
# 94  CA-2015-149587 2015-01-31    NS-18640     Хувь хүн        NaN
# 95  US-2017-109484 2017-11-06    JR-15700       Гишүүн    Хан-Уул
# 98  CA-2016-149223 2016-09-06    CV-12805  Байгууллага  Чингэлтэй
# 99  CA-2016-158568 2016-08-29    DK-12835       Гишүүн  Чингэлтэй
#
#                            Category             Product Name  Discount  \
# 0                    Чихэр, печенье       Shokolinsen 250 гр      0.00
# 1            OO ийн цаас, сальфетка      Хэрэглээ 00ийн цаас      0.00
# 2                    Чихэр, печенье  Алимтай жигнэмэг 230 гр      0.00
# 3                         Хиам бууз      Золотой янта 500 гр      0.00
# 4                          Ундаа ус             Punch 450 мл      0.00
# ..                              ...                      ...       ...
# 93                        Архи пиво           Алтантүрүү 0.5      0.00
# 94                          Зайрмаг       Фифти фифти 180 гр      0.00
# 95  Компот варенье, хүүхдийн тэжээл            Hainich нухаш      0.03
# 98                        Архи пиво              Арвай 0.100      0.00
# 99                     Бэлэн гоймон     Тэйсти гоймон 110 гр      0.03
#
#       Sales
# 0    6600.0
# 1    1500.0
# 2    6200.0
# 3   14000.0
# 4    2300.0
# ..      ...
# 93  37500.0
# 94   5500.0
# 95   3201.0
# 98  12000.0
# 99  12222.0
#
# [98 rows x 9 columns]

# %%
df3 = df2.fillna(method = 'bfill')
df3
# Out:
#           Order ID Order Date Customer ID      Segment     Region  \
# 0   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 1   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 2   CA-2016-138688 2016-06-12    MO-17950  Байгууллага    Хан-Уул
# 3   US-2015-108966 2015-10-11    JO-15550     Хувь хүн    Хан-Уул
# 4   US-2015-108966 2015-10-11    JO-15550     Хувь хүн    Хан-Уул
# ..             ...        ...         ...          ...        ...
# 93  CA-2015-149587 2015-01-31    NS-18640     Хувь хүн    Хан-Уул
# 94  CA-2015-149587 2015-01-31    NS-18640     Хувь хүн    Хан-Уул
# 95  US-2017-109484 2017-11-06    JR-15700       Гишүүн    Хан-Уул
# 98  CA-2016-149223 2016-09-06    CV-12805  Байгууллага  Чингэлтэй
# 99  CA-2016-158568 2016-08-29    DK-12835       Гишүүн  Чингэлтэй
#
#                            Category             Product Name  Discount  \
# 0                    Чихэр, печенье       Shokolinsen 250 гр      0.00
# 1            OO ийн цаас, сальфетка      Хэрэглээ 00ийн цаас      0.00
# 2                    Чихэр, печенье  Алимтай жигнэмэг 230 гр      0.00
# 3                         Хиам бууз      Золотой янта 500 гр      0.00
# 4                          Ундаа ус             Punch 450 мл      0.00
# ..                              ...                      ...       ...
# 93                        Архи пиво           Алтантүрүү 0.5      0.00
# 94                          Зайрмаг       Фифти фифти 180 гр      0.00
# 95  Компот варенье, хүүхдийн тэжээл            Hainich нухаш      0.03
# 98                        Архи пиво              Арвай 0.100      0.00
# 99                     Бэлэн гоймон     Тэйсти гоймон 110 гр      0.03
#
#       Sales
# 0    6600.0
# 1    1500.0
# 2    6200.0
# 3   14000.0
# 4    2300.0
# ..      ...
# 93  37500.0
# 94   5500.0
# 95   3201.0
# 98  12000.0
# 99  12222.0
#
# [98 rows x 9 columns]

# %%
df4 = df2.fillna(method = 'ffill')
df4
# Out:
#           Order ID Order Date Customer ID      Segment     Region  \
# 0   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 1   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 2   CA-2016-138688 2016-06-12    MO-17950  Байгууллага    Хан-Уул
# 3   US-2015-108966 2015-10-11    JO-15550     Хувь хүн    Хан-Уул
# 4   US-2015-108966 2015-10-11    JO-15550     Хувь хүн    Хан-Уул
# ..             ...        ...         ...          ...        ...
# 93  CA-2015-149587 2015-01-31    NS-18640     Хувь хүн  Чингэлтэй
# 94  CA-2015-149587 2015-01-31    NS-18640     Хувь хүн  Чингэлтэй
# 95  US-2017-109484 2017-11-06    JR-15700       Гишүүн    Хан-Уул
# 98  CA-2016-149223 2016-09-06    CV-12805  Байгууллага  Чингэлтэй
# 99  CA-2016-158568 2016-08-29    DK-12835       Гишүүн  Чингэлтэй
#
#                            Category             Product Name  Discount  \
# 0                    Чихэр, печенье       Shokolinsen 250 гр      0.00
# 1            OO ийн цаас, сальфетка      Хэрэглээ 00ийн цаас      0.00
# 2                    Чихэр, печенье  Алимтай жигнэмэг 230 гр      0.00
# 3                         Хиам бууз      Золотой янта 500 гр      0.00
# 4                          Ундаа ус             Punch 450 мл      0.00
# ..                              ...                      ...       ...
# 93                        Архи пиво           Алтантүрүү 0.5      0.00
# 94                          Зайрмаг       Фифти фифти 180 гр      0.00
# 95  Компот варенье, хүүхдийн тэжээл            Hainich нухаш      0.03
# 98                        Архи пиво              Арвай 0.100      0.00
# 99                     Бэлэн гоймон     Тэйсти гоймон 110 гр      0.03
#
#       Sales
# 0    6600.0
# 1    1500.0
# 2    6200.0
# 3   14000.0
# 4    2300.0
# ..      ...
# 93  37500.0
# 94   5500.0
# 95   3201.0
# 98  12000.0
# 99  12222.0
#
# [98 rows x 9 columns]
